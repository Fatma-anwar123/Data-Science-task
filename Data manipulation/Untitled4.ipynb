# %%
import numpy as np
import pandas as pd

# %%
drinkMenu_data = pd.read_csv(r"E:\task\task\Data-science task\drinkMenu.csv") #Reading Csv file
###Data preparation
#Remove Duplicates


df=drinkMenu_data.drop_duplicates()



#fill null value
df.fillna(value=-1, method=None,inplace=True)

#Drop unnecessary Columns
df.drop(df.columns[[5, 6, 7,8,9,13,14,15,16]], axis=1, inplace=True)
print(df)
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
#Data Visualisations
#Q1. Which drink has the highest calories from the dataset?
import seaborn as sns
plt.figure(figsize=(10,8))
bar_cal = sns.barplot(x="Calories", y="Beverage_category", data=df)
plt.ylabel("")

""""
import matplotlib.pyplot as plt
x= df["Calories"]
y=df["Beverage_category"]

plt.plot(x, y)
plt.xlabel("Calories")
plt.ylabel("Beverage_category")
plt.title('Highest Calories Drink ')"""
# Out:
# '"\nimport matplotlib.pyplot as plt\nx= df["Calories"]\ny=df["Beverage_category"]\n\nplt.plot(x, y)\nplt.xlabel("Calories")\nplt.ylabel("Beverage_category")\nplt.title(\'Highest Calories Drink \')'

# %%
#Data Visualisations
#Highest Sugar Drink
plt.figure(figsize=(10,8))
bar_cal = sns.barplot(x=" Sugars (g)", y="Beverage_category", data=df)
plt.ylabel("")

""""
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x= df[" Sugars (g)"]
y=df["Beverage_category"]

figure(figsize=(8,6), dpi=250)

plt.plot(x, y)
plt.xlabel(" Sugars")
plt.ylabel("Beverage_category")
plt.title('Highest sugar Drink ')

sug=df[" Sugars (g)"].max()"""
# Out:
# '"\nimport matplotlib.pyplot as plt\nfrom matplotlib.pyplot import figure\nx= df[" Sugars (g)"]\ny=df["Beverage_category"]\n\nfigure(figsize=(8,6), dpi=250)\n\nplt.plot(x, y)\nplt.xlabel(" Sugars")\nplt.ylabel("Beverage_category")\nplt.title(\'Highest sugar Drink \')\n\nsug=df[" Sugars (g)"].max()'
